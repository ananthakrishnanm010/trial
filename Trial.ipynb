# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Read dataset

# %% [markdown]
# #EDA

# %% [markdown]
# #Preprocessing

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Duplicate Removal

# %% [markdown]
# ### Missing Value Handling

# %% [markdown]
# ##Data Transformation

# %% [markdown]
# ###Scaling

# %% [markdown]
# ### Encoding

# %% [markdown]
# #Data Split

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Linear Regression
