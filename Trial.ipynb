# %% [markdown]
# <a href="https://colab.research.google.com/github/ananthakrishnanm010/trial/blob/main/Trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %% [markdown]
# #Read dataset

# %% [markdown]
# #EDA

# %% [markdown]
# #Preprocessing

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Duplicate Removal

# %% [markdown]
# ### Missing Value Handling

# %% [markdown]
# ##Data Transformation

# %% [markdown]
# ###Scaling

# %% [markdown]
# ### Encoding

# %% [markdown]
# #Data Split

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Linear Regression
